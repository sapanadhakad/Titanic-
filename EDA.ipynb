# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('D:/dataset/tested.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.shape
# Out:
# (418, 12)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data['Fare'].fillna(data['Fare'].mean(),inplace =True)

# %%
data.drop(columns=['Cabin'],inplace = True)#column

# %%
data['Age'].fillna(data['Age'].mean(),inplace =True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data['Parch'].value_counts()
# Out:
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: Parch, dtype: int64

# %%
data['SibSp'].value_counts()#error count
# Out:
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: SibSp, dtype: int64

# %%
data['Survived']=data['Survived'].astype('category')

# %%
data['Pclass']=data['Pclass'].astype('category')

# %%
data['Sex']=data['Sex'].astype('category')
data['Age']=data['Age'].astype('int')
data['Embarked']=data['Embarked'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    category
#  2   Pclass       418 non-null    category
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    category
#  5   Age          418 non-null    int32
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Embarked     418 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 23.5+ KB

# %%
data.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000   30.191388    0.447368    0.392344   35.627188
# std     120.810458   12.654104    0.896760    0.981429   55.840500
# min     892.000000    0.000000    0.000000    0.000000    0.000000
# 25%     996.250000   23.000000    0.000000    0.000000    7.895800
# 50%    1100.500000   30.000000    0.000000    0.000000   14.454200
# 75%    1204.750000   35.750000    1.000000    0.000000   31.500000
# max    1309.000000   76.000000    8.000000    9.000000  512.329200

# %%
#Preprocessing

# %%
sns.countplot(data['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
death_percent = (data['Survived'].value_counts().values[0]/418)*100#use round function
death_percent
# Out:
# 63.63636363636363

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data.sample(5)
# Out:
#      PassengerId Survived Pclass                            Name     Sex  Age  \
# 94           986        0      1             Birnbaum, Mr. Jakob    male   25
# 257         1149        0      3           Niklasson, Mr. Samuel    male   28
# 365         1257        1      3  Sage, Mrs. John (Annie Bullen)  female   30
# 416         1308        0      3             Ware, Mr. Frederick    male   30
# 237         1129        0      3             Baccos, Mr. Raffull    male   20
#
#      SibSp  Parch    Ticket    Fare Embarked
# 94       0      0     13905  26.000        C
# 257      0      0    363611   8.050        S
# 365      1      9  CA. 2343  69.550        S
# 416      0      0    359309   8.050        S
# 237      0      0      2679   7.225        C

# %%
data['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
sns.countplot(data['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
data['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
(data['Pclass'].value_counts()/418)*100
# Out:
# 3    52.153110
# 1    25.598086
# 2    22.248804
# Name: Pclass, dtype: float64

# %%
sns.countplot(data['Sex'])
data['Sex'].value_counts()
(data['Sex'].value_counts()/418)*100
# Out:
# male      63.636364
# female    36.363636
# Name: Sex, dtype: float64

# %%
data['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
sns.distplot(data['Age'])
print(data['Age'].skew())#-0.5to 0.5 prove it normal distribution
print(data['Age'].kurt())
# Out:
# 0.516080054627597
# 0.9003780571212805

# %%
sns.boxplot(data['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
print("People with age in between 60 and 70 are",data[(data['Age']>60) & (data['Age']<70)].shape[0])
# Out:
# People with age in between 60 and 70 are 9

# %%
print(data[(data['Age']>=70) & (data['Age']<=75)].shape[0])
# Out:
# 0

# %%
sns.distplot(data['Fare'])#right skew
data['Fare'].skew()
data['Fare'].kurt()
# Out:
# 17.971266196944526

# %%
data['Fare'].skew()
# Out:
# 3.6915998329393105

# %%
data['Fare'].kurt()
# Out:
# 17.971266196944526

# %%
sns.boxplot(data['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
print("People with fare in between $200 and $500",data[(data['Fare']>200) & (data['Fare']<300)].shape[0])
# Out:
# People with fare in between $200 and $500 17

# %%
#Multivariate Analysis

# %%
sns.countplot(data['Survived'],hue = data['Embarked'])
pd.crosstab(data['Embarked'],data['Survived']).apply(lambda r :round((r/r.sum())*100,1),axis =1)
# Out:
# Survived     0     1
# Embarked
# C         60.8  39.2
# Q         47.8  52.2
# S         67.4  32.6

# %%
plt.figure(figsize = (15,6))
sns.distplot(data[data['Survived']==0]['Age'])
sns.distplot(data[data['Survived']==1]['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize = (15,6))
sns.distplot(data[data['Survived']==0]['Fare'])
sns.distplot(data[data['Survived']==1]['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True,fmt = '0.1f')
# Out:
# <AxesSubplot:>

# %%
data.sample(5)
# Out:
#      PassengerId Survived Pclass                                  Name  \
# 20           912        0      1                Rothschild, Mr. Martin
# 358         1250        0      3                  O'Keefe, Mr. Patrick
# 306         1198        0      1  Allison, Mr. Hudson Joshua Creighton
# 331         1223        0      1          Dulles, Mr. William Crothers
# 169         1061        1      3          Hellstrom, Miss. Hilda Maria
#
#         Sex  Age  SibSp  Parch    Ticket      Fare Embarked
# 20     male   55      1      0  PC 17603   59.4000        C
# 358    male   30      0      0    368402    7.7500        Q
# 306    male   30      1      2    113781  151.5500        S
# 331    male   39      0      0  PC 17580   29.7000        C
# 169  female   22      0      0      7548    8.9625        S

# %%
data['family_size'] = data['Parch']+data['SibSp']
data.sample(5)
# Out:
#      PassengerId Survived Pclass  \
# 204         1096        0      2
# 234         1126        0      1
# 65           957        1      2
# 314         1206        1      1
# 110         1002        0      2
#
#                                                   Name     Sex  Age  SibSp  \
# 204                           Andrew, Mr. Frank Thomas    male   25      0
# 234                          Cumings, Mr. John Bradley    male   39      1
# 65   Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female   30      0
# 314              White, Mrs. John Stuart (Ella Holmes)  female   55      0
# 110                           Stanton, Mr. Samuel Ward    male   41      0
#
#      Parch        Ticket      Fare Embarked  family_size
# 204      0    C.A. 34050   10.5000        S            0
# 234      0      PC 17599   71.2833        C            1
# 65       0  F.C.C. 13534   21.0000        S            0
# 314      0      PC 17760  135.6333        C            0
# ...

# %%
def family_type(number):
    if number == 0:
        return 'Alone'
    elif number > 0 and number <= 4:
        return 'Mediu'
    else:
        return 'Large'

# %%
data['family_type'] = data[family_size].apply(family_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7608\869789995.py in <module>
# ----> 1 data['family_type'] = data[family_size].apply(family_type)
#
# NameError: name 'family_size' is not defined

# %%
data.sample(5)

# %%
data.drop(columns = ['SibSp','Parch','family_size'],inplace = True)

# %%
data.sample(5)

# %%
pd.crosstab(data['family_type'],data['Survived']).apply(lambda r:round((r/r.sum())*100,1),axis=1)

# %%
data = data[data['Age']<(data['Age'].mean()+3*data['Age'].std())]
data.shape

# %%
data.isnull().sum()

# %%
data['Fare'].fillna(data['Fare'].mean(),inplace =True)

# %%
data.sample(5)
# Out:
#      PassengerId Survived Pclass                           Name     Sex  Age  \
# 113         1005        1      3       Buckley, Miss. Katherine  female   18
# 59           951        1      1    Chaudanson, Miss. Victorine  female   36
# 335         1227        0      1       Maguire, Mr. John Edward    male   30
# 57           949        0      3  Abelseth, Mr. Olaus Jorgensen    male   25
# 145         1037        0      3      Vander Planke, Mr. Julius    male   31
#
#        Ticket      Fare Embarked family_type
# 113    329944    7.2833        Q       Alone
# 59   PC 17608  262.3750        C       Alone
# 335    110469   26.0000        S       Alone
# 57     348122    7.6500        S       Alone
# 145    345763   18.0000        S       Mediu

# %%
data.tail()
# Out:
#      PassengerId Survived Pclass                          Name     Sex  Age  \
# 413         1305        0      3            Spector, Mr. Woolf    male   30
# 414         1306        1      1  Oliva y Ocana, Dona. Fermina  female   39
# 415         1307        0      3  Saether, Mr. Simon Sivertsen    male   38
# 416         1308        0      3           Ware, Mr. Frederick    male   30
# 417         1309        0      3      Peter, Master. Michael J    male   30
#
#                  Ticket      Fare Embarked family_type
# 413           A.5. 3236    8.0500        S       Alone
# 414            PC 17758  108.9000        C       Alone
# 415  SOTON/O.Q. 3101262    7.2500        S       Alone
# 416              359309    8.0500        S       Alone
# 417                2668   22.3583        C       Mediu

# %%
data
# Out:
#      PassengerId Survived Pclass  \
# 0            892        0      3
# 1            893        1      3
# 2            894        0      2
# 3            895        0      3
# 4            896        1      3
# ..           ...      ...    ...
# 413         1305        0      3
# 414         1306        1      1
# 415         1307        0      3
# 416         1308        0      3
# 417         1309        0      3
#
#                                              Name     Sex  Age  \
# 0                                Kelly, Mr. James    male   34
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47
# 2                       Myles, Mr. Thomas Francis    male   62
# 3                                Wirz, Mr. Albert    male   27
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22
# ..                                            ...     ...  ...
# 413                            Spector, Mr. Woolf    male   30
# ...

# %%
pd.get_dummies(data=data,columns=['Pclass','Sex','Embarked','family_type'],drop_first=True)
# Out:
#      PassengerId Survived                                          Name  Age  \
# 0            892        0                              Kelly, Mr. James   34
# 1            893        1              Wilkes, Mrs. James (Ellen Needs)   47
# 2            894        0                     Myles, Mr. Thomas Francis   62
# 3            895        0                              Wirz, Mr. Albert   27
# 4            896        1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   22
# ..           ...      ...                                           ...  ...
# 413         1305        0                            Spector, Mr. Woolf   30
# 414         1306        1                  Oliva y Ocana, Dona. Fermina   39
# 415         1307        0                  Saether, Mr. Simon Sivertsen   38
# 416         1308        0                           Ware, Mr. Frederick   30
# 417         1309        0                      Peter, Master. Michael J   30
#
# ...

# %%
plt.figure(figsize=(15,6))
sns.heatmap(data.corr(),cmap = 'gray')
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 417
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Survived     417 non-null    category
#  2   Pclass       417 non-null    category
#  3   Name         417 non-null    object
#  4   Sex          417 non-null    category
#  5   Age          417 non-null    int32
#  6   Ticket       417 non-null    object
#  7   Fare         417 non-null    float64
#  8   Embarked     417 non-null    category
#  9   family_type  417 non-null    object
# dtypes: category(4), float64(1), int32(1), int64(1), object(3)
# memory usage: 23.3+ KB

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0             0
#         1           151
# male    0           266
#         1             0
# Name: Survived, dtype: int64

# %%
data.describe()

# %%
https://www.kaggle.com/code/ash316/eda-to-prediction-dietanic?scriptVersionId=2739619&cellId=12

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_3136f_row0_col0, #T_3136f_row0_col1, #T_3136f_row0_col2, #T_3136f_row0_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3136f_row1_col0 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_3136f_row1_col1 {
#   background-color: #79bc66;
#   color: #000000;
# }
# #T_3136f_row1_col2 {
#   background-color: #7ebe66;
#   color: #000000;
# }
# #T_3136f_row1_col3 {
#   background-color: #91c866;
#   color: #000000;
# }
# #T_3136f_row2_col0, #T_3136f_row2_col1, #T_3136f_row2_col2, #T_3136f_row2_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3136f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_3136f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_3136f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_3136f_level0_col2" class="col_heading level0 col2" >3</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
pd.crosstab(data.Pclass,data.Survived,margins =True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style type="text/css">
# #T_b8534_row0_col0, #T_b8534_row1_col1, #T_b8534_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_b8534_row0_col1 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# #T_b8534_row0_col2 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_b8534_row1_col0 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_b8534_row2_col0 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_b8534_row2_col1 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_b8534_row2_col2 {
#   background-color: #9dce66;
#   color: #000000;
# }
# #T_b8534_row3_col0, #T_b8534_row3_col1, #T_b8534_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b8534">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_b8534_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b8534_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
f,ax = plt.subplots(1,2,figsize = (18,8))
data['Pclass'].value_counts().plot.bar(color = 'Brown',ax = ax[0])
ax[0].set_title('Number of Passenger By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue = 'Survived',data = data, ax =ax[1])
ax[1].set_title('Pclass :Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins = True).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d3b03_row0_col0, #T_d3b03_row0_col1, #T_d3b03_row0_col2, #T_d3b03_row0_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d3b03_row1_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_d3b03_row1_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_d3b03_row1_col2 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_d3b03_row1_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_d3b03_row2_col0, #T_d3b03_row2_col1, #T_d3b03_row2_col2, #T_d3b03_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d3b03">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_d3b03_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_d3b03_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_d3b03_level0_col2" class="col_heading level0 col2" >3</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()
